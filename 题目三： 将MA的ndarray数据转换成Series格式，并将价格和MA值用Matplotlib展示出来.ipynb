# %%
import talib as ta
import pandas as pd
import numpy as np
data =  pd.read_excel('/Users/janicewoll/Desktop/sz50.xlsx',sheet_name='600036.XSHG', index_col='datetime')
data_frame= pd.DataFrame(data)
data_frame = data['close']
data_frame.values
MA = ta.MA(data_frame.values,10)
print(type(MA))
print(MA[-5:])
# Out:
# <class 'numpy.ndarray'>
# [108.35  108.741 109.176 110.102 111.666]

# %%
MA_Series = pd.Series(MA,index=data['close'].index)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,7))
plt.plot(data['close'])
plt.plot(MA_Series)
plt.show()
